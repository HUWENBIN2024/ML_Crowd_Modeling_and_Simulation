# %%
from chaotic_dynamics import *
# %matplotlib  inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Part 1 : Logistic map
# Given:  the discrete map:  $x_{n+1} =r*x_n(1−x_n), n \in \mathbb{N}, r \in (0, 4]$  </br>
# To Show:
# 1. vary r from 0 to 2. Which bifurcations occur? At which numerical values do you find steady states of the system?</br>
# 2. vary r from 2 to 4 What happens? Describe the behavior</br>
# 3. plot a bifurcation diagram for r between 0 and 4 (x axis), x between 0 and 1(y axis)

# %% [markdown]
# part 1.1</br>
#   vary r from 0 to 2.

# %%
plot_logistic_map(.7, .2)
plot_logistic_map(1.7, .2)
plot_bifurcation_diagram(0,2)

# %% [markdown]
# part 1.2</br>
#   vary r from 2 to 4.

# %%
plot_logistic_map(2.8, .2,)
plot_logistic_map(3.4, .2)
plot_logistic_map(3.5, .2)
plot_logistic_map(3.8, .2)
plot_bifurcation_diagram(2,4)

# %% [markdown]
# part 1.3</br>
#   plot a bifurcation diagram for r between 0 and 4 (x axis), x between 0 and 1(y axis)

# %%
plot_bifurcation_diagram(0,4)

# %% [markdown]
# ### Part 2 : Lorenz attractor
# Given:  a Lorenz system:
# </br> $\frac{\mathrm{dx}}{\mathrm{d}t} = \sigma (y - x)$  &nbsp;  $\frac{\mathrm{dy}}{\mathrm{d}t} = x (\rho - z) - y $ &nbsp;   $\frac{\mathrm{dz}}{\mathrm{d}t} = xy - \beta z$</br>
# To Show: </br>
# a trajectory of the Lorenz attractor starting at (10,10,10)

# %% [markdown]
# part 2.1</br>
# $\sigma = 10, \beta = 8/3, \rho = 28$

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6), sharey=True,subplot_kw={'projection': '3d'})
x1=plot_lorenz_trajectory([10, 10, 10],10,8/3, 28,ax=ax1)
x2=plot_lorenz_trajectory([10+1e-8, 10, 10],10,8/3, 28,ax=ax2)

# %%
comparsion(x1, x2)
# Out:
# The difference between the given points on the trajectory larger than 1 at 24.81s

# %% [markdown]
# part 2.2</br>
# $sigma = 10, \beta = 8/3, \rho = 0.5$

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6), sharey=True,subplot_kw={'projection': '3d'})
x1=plot_lorenz_trajectory([10, 10, 10],10,8/3, 0.5,ax=ax1)
x2=plot_lorenz_trajectory([10+1e-8, 10, 10],10,8/3, 0.5,ax=ax2)

# %%
comparsion(x1, x2)

# %%
bifurcation_diagram_lorenz([10, 10, 10],10,8/3,0.1,28)
