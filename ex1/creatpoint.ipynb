# %%
import  math
import matplotlib.pyplot as plt
import numpy as np
# def return_xy_list(alfa,):
#     pass
r = 40
xa = -11.599
ya = 0.645941173792
x0 = 0
y0 = 0
alfa = 72
list_x=[]
list_y=[]
N=int(360/alfa)
for i in range(N):
    theta=math.atan2(ya,xa)
    theta2=math.atan2(ya,xa)+math.pi
    print (theta,theta2)
    x=x0+r*math.cos(theta-alfa*math.pi/180)
    y = y0 + r * math.sin(theta - alfa*math.pi/180)
    list_x.append(x)
    list_y.append(y)
    xa=x
    ya=y
theta1 = np.arange(0, 2*np.pi, 0.01)
xx = x0 + r * np.cos(theta1)
yy = y0 + r * np.sin(theta1)
fig = plt.figure()
axes = fig.add_subplot(111)
axes.plot(xx, yy)
axes.axis('equal')
plt.title('test')
print (list_x)
print (list_y)
# print list_x[3]
# print list_y[3]
plt.plot(list_x,list_y)
axes.scatter(list_x, list_y, s=90, c='k', marker='x')
plt.show()
# Out:
# 3.0859607319148568 6.22755338550465
# 1.8293236704789395 4.970916324068733
# 0.5726866090430223 3.7142792626328154
# -0.683950452392895 2.457642201196898
# -1.9405875138288122 1.2010051397609809
# [-10.226284533367993, 33.617926328039964, 31.003305635386642, -14.456829681769864, -39.93811774828875]
# [38.6707008553323, 21.67567829163547, -25.274394941893323, -37.29611341081397, 2.2241292057395166]

# %%
import random

# %%
count=0
i = 1
while(i <= 150):
#    j = 42
#    while(j <= 58):
      x=random.randint(41,60)
      y=random.randint(81,121)
      text =print  ( "[","[",x, "," ,y ,"]",",",round(random.uniform(1,2),2),"]",end=', ')
    #   j = j + 1
      count +=1
      if count%10 == 0:
       print(end="\n")
      i = i + 1
# Out:
# [ [ 50 , 114 ] , 1.68 ], [ [ 55 , 116 ] , 1.61 ], [ [ 54 , 105 ] , 1.37 ], [ [ 44 , 104 ] , 1.03 ], [ [ 43 , 106 ] , 1.71 ], [ [ 51 , 93 ] , 1.06 ], [ [ 44 , 108 ] , 1.2 ], [ [ 41 , 97 ] , 1.94 ], [ [ 53 , 107 ] , 1.87 ], [ [ 56 , 110 ] , 1.07 ],
# [ [ 42 , 89 ] , 1.76 ], [ [ 43 , 120 ] , 1.98 ], [ [ 43 , 85 ] , 1.66 ], [ [ 59 , 109 ] , 1.03 ], [ [ 54 , 97 ] , 1.91 ], [ [ 43 , 120 ] , 1.81 ], [ [ 41 , 81 ] , 1.32 ], [ [ 46 , 106 ] , 1.56 ], [ [ 49 , 93 ] , 1.73 ], [ [ 59 , 98 ] , 1.1 ],
# [ [ 60 , 117 ] , 1.72 ], [ [ 56 , 106 ] , 1.43 ], [ [ 60 , 91 ] , 1.52 ], [ [ 55 , 120 ] , 1.84 ], [ [ 60 , 109 ] , 1.51 ], [ [ 46 , 120 ] , 1.91 ], [ [ 51 , 118 ] , 1.89 ], [ [ 44 , 85 ] , 1.41 ], [ [ 51 , 90 ] , 1.87 ], [ [ 57 , 105 ] , 1.49 ],
# [ [ 47 , 102 ] , 1.25 ], [ [ 53 , 111 ] , 1.19 ], [ [ 54 , 118 ] , 1.71 ], [ [ 47 , 108 ] , 1.03 ], [ [ 42 , 105 ] , 1.6 ], [ [ 43 , 113 ] , 1.01 ], [ [ 47 , 95 ] , 1.38 ], [ [ 46 , 108 ] , 1.53 ], [ [ 48 , 104 ] , 1.85 ], [ [ 60 , 113 ] , 1.11 ],
# ...

# %%
count=0
i = 1
while(i <11):
   j = 14
   while(j <= 14):
    #   x=random.randint(1081,1260)
    #   y=random.randint(1501,1529)
      text =print  ( "[","[",i, "," ,j ,"]",",",round(random.uniform(0.5,1.8),2),"]",end=', ')
      j = j + 2
      count +=1
      if count%5 == 0:
       print(end="\n")
   i = i + 2
# Out:
# [ [ 1 , 14 ] , 1.26 ], [ [ 3 , 14 ] , 1.29 ], [ [ 5 , 14 ] , 1.6 ], [ [ 7 , 14 ] , 1.49 ], [ [ 9 , 14 ] , 1.57 ],

# %%
count=0
i =0
while(i <= 12):
   j = 10
   while(j <=10):
    #   x=random.randint(1081,1260)
    #   y=random.randint(1501,1529)
      text =print  ( "[",i, "," ,j ,"]",end=', ')
      j = j + 1
      count +=1
      if count%10 == 0:
       print(end="\n")
   i = i + 2
# Out:
# [ 0 , 10 ], [ 2 , 10 ], [ 4 , 10 ], [ 6 , 10 ], [ 8 , 10 ], [ 10 , 10 ], [ 12 , 10 ],
